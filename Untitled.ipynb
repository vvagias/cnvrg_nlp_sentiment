# %%
import http.client

conn = http.client.HTTPSConnection("skyscanner-skyscanner-flight-search-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "33343fef78mshaf5331908bc46dcp1181e3jsnd0ad5cf92df9"
    }

conn.request("GET", "/apiservices/autosuggest/v1.0/UK/GBP/en-GB/?query=Austin", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "Places" : [ {
#     "PlaceId" : "AUS-sky",
#     "PlaceName" : "Austin-Bergstrom",
#     "CountryId" : "US-sky",
#     "RegionId" : "TX",
#     "CityId" : "AUSA-sky",
#     "CountryName" : "United States"
#   }, {
#     "PlaceId" : "AUM-sky",
#     "PlaceName" : "Austin",
#     "CountryId" : "US-sky",
#     "RegionId" : "MN",
#     "CityId" : "AUMA-sky",
#     "CountryName" : "United States"
#   } ]
# }

# %%
import http.client

conn = http.client.HTTPSConnection("skyscanner-skyscanner-flight-search-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "33343fef78mshaf5331908bc46dcp1181e3jsnd0ad5cf92df9"
    }

conn.request("GET", "/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2021-10-04?inboundpartialdate=2021-12-01", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 124,
#     "Direct" : false,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 1065 ],
#       "OriginId" : 81727,
#       "DestinationId" : 73076,
#       "DepartureDate" : "2021-10-04T00:00:00"
#     },
#     "QuoteDateTime" : "2021-10-04T04:17:00"
#   }, {
#     "QuoteId" : 2,
#     "MinPrice" : 398,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 851 ],
#       "OriginId" : 81727,
#       "DestinationId" : 73076,
#       "DepartureDate" : "2021-10-04T00:00:00"
#     },
#     "QuoteDateTime" : "2021-10-03T07:29:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 1065,
#     "Name" : "Frontier Airlines"
#   }, {
#     "CarrierId" : 851,
#     "Name" : "Alaska Airlines"
#   } ],
#   "Places" : [ {
#     "Name" : "Chicago O'Hare International",
#     "Type" : "Station",
#     "PlaceId" : 73076,
#     "IataCode" : "ORD",
#     "SkyscannerCode" : "ORD",
#     "CityName" : "Chicago",
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("weatherbit-v1-mashape.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com",
    'x-rapidapi-key': "33343fef78mshaf5331908bc46dcp1181e3jsnd0ad5cf92df9"
    }

conn.request("GET", "/forecast/minutely?lat=35.5&lon=-78.5", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":[{"timestamp_utc":"2021-10-04T13:42:00","snow":0,"temp":21.4,"timestamp_local":"2021-10-04T09:42:00","ts":1633354920,"precip":0},{"timestamp_utc":"2021-10-04T13:43:00","snow":0,"temp":21.5,"timestamp_local":"2021-10-04T09:43:00","ts":1633354980,"precip":0},{"timestamp_utc":"2021-10-04T13:44:00","snow":0,"temp":21.5,"timestamp_local":"2021-10-04T09:44:00","ts":1633355040,"precip":0},{"timestamp_utc":"2021-10-04T13:45:00","snow":0,"temp":21.5,"timestamp_local":"2021-10-04T09:45:00","ts":1633355100,"precip":0},{"timestamp_utc":"2021-10-04T13:46:00","snow":0,"temp":21.5,"timestamp_local":"2021-10-04T09:46:00","ts":1633355160,"precip":0},{"timestamp_utc":"2021-10-04T13:47:00","snow":0,"temp":21.6,"timestamp_local":"2021-10-04T09:47:00","ts":1633355220,"precip":0},{"timestamp_utc":"2021-10-04T13:48:00","snow":0,"temp":21.6,"timestamp_local":"2021-10-04T09:48:00","ts":1633355280,"precip":0},{"timestamp_utc":"2021-10-04T13:49:00","snow":0,"temp":21.6,"timestamp_local":"2021-10-04T09:
# ...

# %%
import json
j = json.loads(data.decode("utf-8"))
j['data']
# Out:
# [{'timestamp_utc': '2021-10-04T13:42:00',
#   'snow': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-10-04T09:42:00',
#   'ts': 1633354920,
#   'precip': 0},
#  {'timestamp_utc': '2021-10-04T13:43:00',
#   'snow': 0,
#   'temp': 21.5,
#   'timestamp_local': '2021-10-04T09:43:00',
#   'ts': 1633354980,
#   'precip': 0},
#  {'timestamp_utc': '2021-10-04T13:44:00',
#   'snow': 0,
#   'temp': 21.5,
#   'timestamp_local': '2021-10-04T09:44:00',
#   'ts': 1633355040,
#   'precip': 0},
#  {'timestamp_utc': '2021-10-04T13:45:00',
#   'snow': 0,
#   'temp': 21.5,
#   'timestamp_local': '2021-10-04T09:45:00',
#   'ts': 1633355100,
#   'precip': 0},
#  {'timestamp_utc': '2021-10-04T13:46:00',
#   'snow': 0,
#   'temp': 21.5,
#   'timestamp_local': '2021-10-04T09:46:00',
#   'ts': 1633355160,
#   'precip': 0},
#  {'timestamp_utc': '2021-10-04T13:47:00',
#   'snow': 0,
#   'temp': 21.6,
#   'timestamp_local': '2021-10-04T09:47:00',
#   'ts': 1633355220,
#   'precip': 0},
# ...
